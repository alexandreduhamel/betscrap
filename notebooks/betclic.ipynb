# %%
from bs4 import BeautifulSoup
import urllib
import urllib.error
import urllib.request
import json
import pandas as pd
import numpy as np
import time



URL_HOME = 'https://www.betclic.fr/'

# %%
def request_get_html(url):
    req = urllib.request.Request(
        url, 
        headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
    })
    page = urllib.request.urlopen(req, timeout=10).read()
    parser = BeautifulSoup(page, 'html.parser')
    return parser

# %%
a = request_get_html(URL_HOME)

# %%
b = a.find_all(attrs={'type': "application/json"})[0].text

# %%
c = json.loads(b)

# %%
for k in c.keys():
    if ('/sports?' in k):
        print(k)
        print(c[k])
        print()
# Out:
# G.json./ext/sports-offer/pub/v3/sports?includeCompetitionGroupsForLayout=EventCategory&includeTops=true
# ...

# %%
d = c['G.json./ext/sports-offer/pub/v3/sports?includeCompetitionGroupsForLayout=EventCategory&includeTops=true']['body']['sports']
for l in d:
    print(l)
    for k, v in l.items():
        print(k)
        print(v)
        print()
    print(URL_HOME + l['name'].lower() + '-s' + str(l['id']))
# Out:
# {'openMarketCount': 55830, 'mobileSportTypeLayout': 1, 'top': {'isTop': True, 'order': 1}, 'competitions': [{'openMarketCount': 3060, 'country': {'code': 'FR', 'name': 'France', 'top': {'isTop': True, 'order': 1}, 'openMarketCountForSport': 4463}, 'allSportsTop': {'isTop': True, 'order': 2}, 'sportTop': {'isTop': True, 'order': 1}, 'id': 4, 'name': 'Ligue 1 Uber Eats®', 'position': 0, 'iafc': False, 'displayImage': True, 'logoRatio': 1}, {'openMarketCount': 3171, 'country': {'code': 'ES', 'name': 'Espagne', 'top': {'isTop': True, 'order': 2}, 'openMarketCountForSport': 5481}, 'allSportsTop': {'isTop': True, 'order': 3}, 'sportTop': {'isTop': True, 'order': 2}, 'id': 7, 'name': 'Espagne Liga Primera', 'position': 0, 'iafc': False, 'displayImage': False, 'logoRatio': 0}, {'openMarketCount': 1653, 'country': {'code': 'EN', 'name': 'Angleterre', 'top': {'isTop': True, 'order': 3}, 'openMarketCountForSport': 4305}, 'allSportsTop': {'isTop': True, 'order': 5}, 'sportTop': {'isTop': True, '
# ...

# %%
c['G.json./ext/sports-offer/pub/v4/sports/1?hasSwitchMtc=true&limit=20&offset=0&sortBy=ByLiveRankingPreliveDate']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 c['G.json./ext/sports-offer/pub/v4/sports/1']
#
# KeyError: 'G.json./ext/sports-offer/pub/v4/sports/1'

# %%
for line in b:
    print(line)
# Out:
# <script id="ng-state" type="application/json">{"G.json./ext/sports-offer/pub/v3/sports?includeCompetitionGroupsForLayout=EventCategory&includeTops=true":{"body":{"sports":[{"openMarketCount":51626,"mobileSportTypeLayout":1,"top":{"isTop":true,"order":1},"competitions":[{"openMarketCount":2850,"country":{"code":"EN","name":"Angleterre","top":{"isTop":true,"order":2},"openMarketCountForSport":5039},"allSportsTop":{"isTop":true,"order":2},"sportTop":{"isTop":true,"order":1},"id":3,"name":"Angl. Premier League","position":0,"iafc":false,"displayImage":false,"logoRatio":0},{"openMarketCount":1515,"country":{"code":"PT","name":"Portugal","top":{"isTop":true,"order":3},"openMarketCountForSport":2485},"allSportsTop":{"isTop":true,"order":3},"sportTop":{"isTop":true,"order":2},"id":32,"name":"Liga Portugal Betclic","position":0,"iafc":false,"displayImage":true,"logoRatio":1},{"openMarketCount":2937,"country":{"code":"ES","name":"Espagne","top":{"isTop":true,"order":4},"openMarketCountForSport
# ...

# %%
for line in parser.find_all(attrs={'class': 'oddMatchName'}):
    print(line)
    break
# Out:
# <span class="oddMatchName ng-tns-c4057645750-0 ng-star-inserted" style="">
# <!--ngtns-->
# <span class="ellipsis ng-tns-c4057645750-0 ng-star-inserted">Deportivo La Equ</span>
# <span class="clip ng-tns-c4057645750-0 ng-star-inserted">idad</span>
# <!-- --><!-- --></span>

# %%
# Out:
# 1

# %%
for line in parser.find_all(attrs='ng-tns-c4057645750-0'):
    print(line)
    break
# Out:
# <sports-selections-selection class="ng-tns-c4057645750-0 oddButton ng-star-inserted" ngh="33"><div bc-gb-buttonspinner="" class="oddButtonWrapper loading ng-tns-c4057645750-0 ng-trigger ng-trigger-oddsStateAnimation" title="Deportivo La Equidad">
# <!--ngtns-->
# <span class="oddMatchName ng-tns-c4057645750-0 ng-star-inserted" style="">
# <!--ngtns-->
# <span class="ellipsis ng-tns-c4057645750-0 ng-star-inserted">Deportivo La Equ</span>
# <span class="clip ng-tns-c4057645750-0 ng-star-inserted">idad</span>
# <!-- --><!-- --></span>
# <!-- --><!-- -->
# <!--ngtns-->
# <span class="oddValue ng-tns-c4057645750-0 ng-star-inserted" style="">1,41</span>
# <!-- --><!-- --><!-- --><!-- --><span class="loader_spinner ng-tns-c4057645750-0"></span><span class="loader_check ng-tns-c4057645750-0"></span></div>
# <!-- --></sports-selections-selection>

# %%
ng-tns-c4057645750-0
